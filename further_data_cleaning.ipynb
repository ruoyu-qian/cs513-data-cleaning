# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)

# %%
data = pd.read_csv('./data/farmersmarkets.csv', low_memory=False)

# %%
data.columns
# Out:
# Index(['FMID', 'MarketName', 'Website', 'Facebook', 'Twitter', 'Youtube',
#        'OtherMedia', 'Street', 'City', 'County', 'State', 'zip',
#        'Season1Date 1', 'Season1Time 1', 'Season1Time 2', 'Season1Time 3',
#        'Season1Time 4', 'Season1Time 5', 'Season1Time 6', 'Season1Time 7',
#        'Season1Time 8', 'Season2Date 1', 'Season2Time 1', 'Season2Time 2',
#        'Season2Time 3', 'Season2Time 4', 'Season2Time 5', 'Season2Time 6',
#        'Season2Time 7', 'Season2Time 8', 'Season3Date 1', 'Season3Time 1',
#        'Season3Time 2', 'Season3Time 3', 'Season3Time 4', 'Season3Time 5',
#        'Season3Time 6', 'Season3Time 7', 'Season4Date 1', 'Season4Time 1',
#        'Season4Time 2', 'Season4Time 3', 'x', 'y', 'Location', 'Credit', 'WIC',
#        'WICcash', 'SFMNP', 'SNAP', 'Organic', 'Bakedgoods', 'Cheese', 'Crafts',
#        'Flowers', 'Eggs', 'Seafood', 'Herbs', 'Vegetables', 'Honey', 'Jams',
#        'Maple', 'Meat', 'Nursery', 'Nuts', 'Plants', 'Poultry', 'Prepared',
#        'Soap', 'Trees', 'Wine', 'Coffee', 'Beans', 'Fruits', 'Grains',
#        'Juices', 'Mushrooms', 'PetFood', 'Tofu', 'WildHarvested',
#        'updateTime'],
#       dtype='object')

# %% [markdown]
# ## Address

# %%
address = data[['FMID', 'MarketName', 'Street', 'City', 'County', 'State', 'zip', 'x', 'y', 'Location', 'updateTime']]
address
# Out:
#          FMID                                       MarketName  \
# 0     1012063  Caledonia Farmers Market Association - Danville
# 1     1011871                Stearns Homestead Farmers' Market
# 2     1011878                                  100 Mile Market
# 3     1009364                106 S. Main Street Farmers Market
# 4     1010691              10th Steet Community Farmers Market
# ...       ...                                              ...
# 8660  1004767                   Zia Bernalillo Farmers' Market
# 8661  1000778                         Zimmerman Farmers Market
# 8662  1012380                       Zion Canyon Farmers Market
# 8663  1004686                        Zionsville Farmers Market
# 8664  1011418                        Zona Rosa Farmers' Market
#
#                           Street         City      County           State  \
# 0                            NaN     Danville   Caledonia         Vermont
# 1                6975 Ridge Road        Parma    Cuyahoga            Ohio
# 2                507 Harrison St    Kalamazoo   Kalamazoo        Michigan
# 3             106 S. Main Street     Six Mile         NaN  South Carolina
# 4         10th Street and Poplar        Lamar      Barton        Missouri
# ...                          ...          ...         ...             ...
# 8660    335 S. Camino del Pueblo   Bernalillo    Sandoval      New Mexico
# 8661     Lions Park, Main Street    Zimmerman   Sherburne       Minnesota
# 8662        1212 Zion Park Blvd.   Springdale  Washington            Utah
# 8663     Hawthorne & Main Street   Zionsville       Boone         Indiana
# 8664  Off of I-29 and Barry Road  Kansas City      Platte        Missouri
#
#         zip           x          y  \
# 0     05828  -72.140305  44.411013
# 1     44130  -81.728597  41.375118
# 2     49007  -85.574887  42.296024
# 3     29682  -82.818700  34.804200
# 4     64759  -94.274619  37.495628
# ...     ...         ...        ...
# 8660    NaN -106.546840  35.313704
# 8661  55398  -93.585014  45.437700
# 8662  84767 -113.004938  37.181501
# 8663  46077  -86.261200  39.949100
# 8664  64153  -94.580864  39.246317
#
#                                                Location            updateTime
# 0                                                   NaN  2018-04-06T12:10:09Z
# 1                                                   NaN  2016-09-04T08:05:17Z
# 2                                                   NaN  2017-03-07T07:20:33Z
# 3                                                   NaN  2013-01-01T00:00:00Z
# 4                                                   NaN  2016-04-10T09:49:46Z
# ...                                                 ...                   ...
# 8660  Faith-based institution (e.g., church, mosque,...  2014-05-06T02:40:25Z
# 8661                                                NaN  2018-03-06T03:44:36Z
# 8662                                                NaN  2016-09-07T05:00:07Z
# 8663                                                NaN  2009-01-01T00:00:00Z
# 8664                                                NaN  2015-04-09T09:48:39Z
#
# [8665 rows x 11 columns]

# %%
last_address = address.sort_values('updateTime').groupby(['Street', 'City', 'County', 'State', 'zip']).apply(lambda x: x.tail(1))
last_address = last_address.reset_index(drop=True)
last_address
# Out:
#          FMID                           MarketName  \
# 0     1004486             St. Clair Farmers Market
# 1     1009078               Hammond Farmers Market
# 2     1005734              Schenectady Greenmarket
# 3     1005692           Dolgeville Farmer's Market
# 4     1004184                Quincy Farmers Market
# ...       ...                                  ...
# 7101  1002374           Chamberlain Farmers Market
# 7102  1010443           Hyde County Farmers Market
# 7103  1000342      rockville centre farmers market
# 7104  1003504  Punta Gorda Downtown Farmers Market
# 7105  1004245            Kinderhook Farmers Market
#
#                                                  Street              City  \
# 0                                   #1 Paul Parks Drive         St. Clair
# 1                                 #2 West Thomas Street           Hammond
# 2     (Nov - April) 432 State Street / (May - Oct) 1...       Schenectady
# 3         (Parking Lot) Between Main St. and Helmer Ave        Dolgeville
# 4                                  0 Denis Ryan Parkway            Quincy
# ...                                                 ...               ...
# 7101                             south main st and 12th       Chamberlain
# 7102                                         south park          Highmore
# 7103                       sunrise high/long beach road  rockville centre
# 7104              taylor street and west olympia avenue       Punta Gorda
# 7105                 village green            green st.        kinderhook
#
#            County          State    zip          x          y  \
# 0        Franklin       Missouri  63077 -90.987401  38.348942
# 1      Tangipahoa      Louisiana  70401 -90.460693  30.504198
# 2     Schenectady       New York  12305 -73.939792  42.814295
# 3        Herkimer       New York  13329 -74.771675  43.112004
# 4         Norfolk  Massachusetts  02169 -71.000020  42.248250
# ...           ...            ...    ...        ...        ...
# 7101        Brule   South Dakota  57325 -99.335551  43.803428
# 7102         Hyde   South Dakota  57345 -99.441501  44.514029
# 7103      Suffolk       New York  11571 -73.627879  40.665243
# 7104    Charlotte        Florida  33950 -82.050202  26.934216
# 7105     Columbia       New York  12106 -73.699830  42.396032
#
#                                                Location            updateTime
# 0                     Local government building grounds  2014-01-04T11:17:00Z
# 1                     Local government building grounds  2015-11-04T08:52:29Z
# 2                                                   NaN  2018-03-06T01:00:11Z
# 3                     Local government building grounds  2014-12-05T01:21:35Z
# 4                     Local government building grounds  2014-02-04T02:41:53Z
# ...                                                 ...                   ...
# 7101  Faith-based institution (e.g., church, mosque,...  2015-09-03T04:20:18Z
# 7102                  Local government building grounds  2014-06-08T09:28:40Z
# 7103                       Private business parking lot  2014-06-05T12:46:00Z
# 7104                                                NaN  2016-06-07T03:57:52Z
# 7105                           Closed-off public street  2013-05-05T09:42:11Z
#
# [7106 rows x 11 columns]

# %%
last_address.to_csv('./data/address.csv', index=False)

# %% [markdown]
# ## Seasons

# %%
seasons = data[['FMID', 'Season1Date 1', 'Season2Date 1', 'Season3Date 1', 'Season4Date 1']]
seasons
# Out:
#          FMID             Season1Date 1 Season2Date 1 Season3Date 1  \
# 0     1012063  06/08/2016 to 10/12/2016           NaN           NaN
# 1     1011871  06/25/2016 to 10/01/2016           NaN           NaN
# 2     1011878  05/04/2016 to 10/12/2016           NaN           NaN
# 3     1009364                       NaN           NaN           NaN
# 4     1010691  04/02/2014 to 11/30/2014           NaN           NaN
# ...       ...                       ...           ...           ...
# 8660  1004767  07/04/2014 to 10/24/2014           NaN           NaN
# 8661  1000778  06/07/2016 to 10/04/2016           NaN           NaN
# 8662  1012380  05/07/2016 to 10/15/2016           NaN           NaN
# 8663  1004686                       NaN           NaN           NaN
# 8664  1011418  06/01/2015 to 09/30/2015           NaN           NaN
#
#      Season4Date 1
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 8660           NaN
# 8661           NaN
# 8662           NaN
# 8663           NaN
# 8664           NaN
#
# [8665 rows x 5 columns]

# %%
seasons = seasons.melt(
    id_vars=["FMID"], 
    var_name="SeasonNum",
    value_name="SeasonDate"
)[['FMID', 'SeasonDate']].dropna().reset_index(drop=True)

seasons
# Out:
#          FMID                SeasonDate
# 0     1012063  06/08/2016 to 10/12/2016
# 1     1011871  06/25/2016 to 10/01/2016
# 2     1011878  05/04/2016 to 10/12/2016
# 3     1010691  04/02/2014 to 11/30/2014
# 4     1002454          July to November
# ...       ...                       ...
# 5896  1012508  01/15/2017 to 01/15/2017
# 5897  1005991            05/01/2015 to
# 5898  1010118  04/14/2016 to 04/14/2016
# 5899  1001875  05/28/2016 to 09/24/2016
# 5900  1009023  12/10/2016 to 12/17/2016
#
# [5901 rows x 2 columns]

# %% [markdown]
# ### Approach #1

# %%
seasons['SeasonDateList'] = seasons['SeasonDate'].str.split(' to ')
seasons
# Out:
#          FMID                SeasonDate            SeasonDateList
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016, 10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016, 10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016, 10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014, 11/30/2014]
# 4     1002454          July to November          [July, November]
# ...       ...                       ...                       ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017, 01/15/2017]
# 5897  1005991            05/01/2015 to             [05/01/2015, ]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016, 04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016, 09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016, 12/17/2016]
#
# [5901 rows x 3 columns]

# %%
seasons.loc[[len(d) > 2 for d in seasons.SeasonDateList],]
# Out:
# Empty DataFrame
# Columns: [FMID, SeasonDate, SeasonDateList]
# Index: []

# %%
seasons.loc[[len(d) < 2 for d in seasons.SeasonDateList],]
# Out:
#          FMID     SeasonDate   SeasonDateList
# 58    1004762  10/25/2014 to  [10/25/2014 to]
# 66    1011322     05/19/2016     [05/19/2016]
# 79    1004846  05/21/2013 to  [05/21/2013 to]
# 90    1011910  04/18/2016 to  [04/18/2016 to]
# 250   1011092  06/07/2016 to  [06/07/2016 to]
# ...       ...            ...              ...
# 5286  1005677  07/28/2016 to  [07/28/2016 to]
# 5303  1010125  12/01/2014 to  [12/01/2014 to]
# 5391  1011180     06/07/2015     [06/07/2015]
# 5416  1001403     10/03/2015     [10/03/2015]
# 5501  1006151     06/07/2013     [06/07/2013]
#
# [117 rows x 3 columns]

# %% [markdown]
# ### Approach #2

# %%
seasons['SeasonDateList'] = seasons['SeasonDate'].str.split('to')
seasons
# Out:
#          FMID                SeasonDate              SeasonDateList
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016 ,  10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016 ,  10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016 ,  10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014 ,  11/30/2014]
# 4     1002454          July to November          [July ,  November]
# ...       ...                       ...                         ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017 ,  01/15/2017]
# 5897  1005991            05/01/2015 to             [05/01/2015 ,  ]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016 ,  04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016 ,  09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016 ,  12/17/2016]
#
# [5901 rows x 3 columns]

# %%
seasons.loc[[len(d) > 2 for d in seasons.SeasonDateList],]
# Out:
#          FMID                         SeasonDate  \
# 43    1001961                     May to October
# 53    1004598                     May to October
# 60    1003469  June 19, 2012 to October 21, 2012
# 102   1002836                   April to October
# 115   1001100                    June to October
# ...       ...                                ...
# 5380  1003731                   April to October
# 5618  1001431                October to December
# 5817  1002222                October to November
# 5837  1002854               September to October
# 5849  1004979               September to October
#
#                            SeasonDateList
# 43                       [May ,  Oc, ber]
# 53                       [May ,  Oc, ber]
# 60    [June 19, 2012 ,  Oc, ber 21, 2012]
# 102                    [April ,  Oc, ber]
# 115                     [June ,  Oc, ber]
# ...                                   ...
# 5380                   [April ,  Oc, ber]
# 5618                [Oc, ber ,  December]
# 5817                [Oc, ber ,  November]
# 5837               [September ,  Oc, ber]
# 5849               [September ,  Oc, ber]
#
# [386 rows x 3 columns]

# %%
seasons.loc[[len(d) < 2 for d in seasons.SeasonDateList],]
# Out:
#          FMID  SeasonDate SeasonDateList
# 66    1011322  05/19/2016   [05/19/2016]
# 548   1012171  06/25/2016   [06/25/2016]
# 807   1002353  05/23/2014   [05/23/2014]
# 1285  1011887  04/17/2016   [04/17/2016]
# 1552  1011719  12/05/2015   [12/05/2015]
# ...       ...         ...            ...
# 5228  1003961  07/13/2013   [07/13/2013]
# 5250  1011897  01/30/2016   [01/30/2016]
# 5391  1011180  06/07/2015   [06/07/2015]
# 5416  1001403  10/03/2015   [10/03/2015]
# 5501  1006151  06/07/2013   [06/07/2013]
#
# [29 rows x 3 columns]

# %% [markdown]
# ### Approach #3

# %%
seasons['SeasonDateList'] = [[d for d in s if d] for s in seasons['SeasonDate'].str.split(' to')]
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016,  10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016,  10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016,  10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014,  11/30/2014]
# 4     1002454          July to November          [July,  November]
# ...       ...                       ...                        ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017,  01/15/2017]
# 5897  1005991            05/01/2015 to             [05/01/2015,  ]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016,  04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016,  09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016,  12/17/2016]
#
# [5901 rows x 3 columns]

# %%
seasons.loc[[len(d) > 2 for d in seasons.SeasonDateList],]
# Out:
# Empty DataFrame
# Columns: [FMID, SeasonDate, SeasonDateList]
# Index: []

# %%
seasons.loc[[len(d) < 2 for d in seasons.SeasonDateList],]
# Out:
#          FMID     SeasonDate SeasonDateList
# 58    1004762  10/25/2014 to   [10/25/2014]
# 66    1011322     05/19/2016   [05/19/2016]
# 79    1004846  05/21/2013 to   [05/21/2013]
# 90    1011910  04/18/2016 to   [04/18/2016]
# 250   1011092  06/07/2016 to   [06/07/2016]
# ...       ...            ...            ...
# 5286  1005677  07/28/2016 to   [07/28/2016]
# 5303  1010125  12/01/2014 to   [12/01/2014]
# 5391  1011180     06/07/2015   [06/07/2015]
# 5416  1001403     10/03/2015   [10/03/2015]
# 5501  1006151     06/07/2013   [06/07/2013]
#
# [117 rows x 3 columns]

# %%
seasons['SeasonStart'] = [s[0] for s in seasons['SeasonDateList']]
seasons['SeasonEnd'] = [s[1] if len(s) > 1 else s[0] for s in seasons['SeasonDateList']]

# %%
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList  \
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016,  10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016,  10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016,  10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014,  11/30/2014]
# 4     1002454          July to November          [July,  November]
# ...       ...                       ...                        ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017,  01/15/2017]
# 5897  1005991            05/01/2015 to             [05/01/2015,  ]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016,  04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016,  09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016,  12/17/2016]
#
#      SeasonStart    SeasonEnd
# 0     06/08/2016   10/12/2016
# 1     06/25/2016   10/01/2016
# 2     05/04/2016   10/12/2016
# 3     04/02/2014   11/30/2014
# 4           July     November
# ...          ...          ...
# 5896  01/15/2017   01/15/2017
# 5897  05/01/2015
# 5898  04/14/2016   04/14/2016
# 5899  05/28/2016   09/24/2016
# 5900  12/10/2016   12/17/2016
#
# [5901 rows x 5 columns]

# %% [markdown]
# ### Approach #4

# %%
seasons['SeasonDate'] = [s.strip() for s in seasons['SeasonDate']]
seasons['SeasonDateList'] = [[d for d in s if d] for s in seasons['SeasonDate'].str.split(' to')]
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016,  10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016,  10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016,  10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014,  11/30/2014]
# 4     1002454          July to November          [July,  November]
# ...       ...                       ...                        ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017,  01/15/2017]
# 5897  1005991             05/01/2015 to               [05/01/2015]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016,  04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016,  09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016,  12/17/2016]
#
# [5901 rows x 3 columns]

# %%
seasons.loc[[len(d) > 2 for d in seasons.SeasonDateList],]
# Out:
# Empty DataFrame
# Columns: [FMID, SeasonDate, SeasonDateList]
# Index: []

# %%
seasons.loc[[len(d) < 2 for d in seasons.SeasonDateList],]
# Out:
#          FMID     SeasonDate SeasonDateList
# 58    1004762  10/25/2014 to   [10/25/2014]
# 66    1011322     05/19/2016   [05/19/2016]
# 79    1004846  05/21/2013 to   [05/21/2013]
# 90    1011910  04/18/2016 to   [04/18/2016]
# 250   1011092  06/07/2016 to   [06/07/2016]
# ...       ...            ...            ...
# 5745  1012351  09/16/2016 to   [09/16/2016]
# 5775  1006826  11/01/2012 to   [11/01/2012]
# 5876  1011004  09/24/2016 to   [09/24/2016]
# 5887  1008842  11/27/2016 to   [11/27/2016]
# 5897  1005991  05/01/2015 to   [05/01/2015]
#
# [134 rows x 3 columns]

# %%
seasons['SeasonStart'] = [s[0] for s in seasons['SeasonDateList']]
seasons['SeasonEnd'] = [s[1] if len(s) > 1 else s[0] for s in seasons['SeasonDateList']]

# %%
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList  \
# 0     1012063  06/08/2016 to 10/12/2016  [06/08/2016,  10/12/2016]
# 1     1011871  06/25/2016 to 10/01/2016  [06/25/2016,  10/01/2016]
# 2     1011878  05/04/2016 to 10/12/2016  [05/04/2016,  10/12/2016]
# 3     1010691  04/02/2014 to 11/30/2014  [04/02/2014,  11/30/2014]
# 4     1002454          July to November          [July,  November]
# ...       ...                       ...                        ...
# 5896  1012508  01/15/2017 to 01/15/2017  [01/15/2017,  01/15/2017]
# 5897  1005991             05/01/2015 to               [05/01/2015]
# 5898  1010118  04/14/2016 to 04/14/2016  [04/14/2016,  04/14/2016]
# 5899  1001875  05/28/2016 to 09/24/2016  [05/28/2016,  09/24/2016]
# 5900  1009023  12/10/2016 to 12/17/2016  [12/10/2016,  12/17/2016]
#
#      SeasonStart    SeasonEnd
# 0     06/08/2016   10/12/2016
# 1     06/25/2016   10/01/2016
# 2     05/04/2016   10/12/2016
# 3     04/02/2014   11/30/2014
# 4           July     November
# ...          ...          ...
# 5896  01/15/2017   01/15/2017
# 5897  05/01/2015   05/01/2015
# 5898  04/14/2016   04/14/2016
# 5899  05/28/2016   09/24/2016
# 5900  12/10/2016   12/17/2016
#
# [5901 rows x 5 columns]

# %%
seasons = seasons.sort_values('FMID')
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList  \
# 1397  1000003  05/31/2014 to 10/31/2014  [05/31/2014,  10/31/2014]
# 5642  1000008  05/21/2016 to 10/29/2016  [05/21/2016,  10/29/2016]
# 3123  1000008  05/23/2015 to 11/01/2015  [05/23/2015,  11/01/2015]
# 5865  1000008  11/05/2016 to 04/29/2017  [11/05/2016,  04/29/2017]
# 4390  1000009  06/14/2014 to 10/11/2014  [06/14/2014,  10/11/2014]
# ...       ...                       ...                        ...
# 2266  1012844  05/06/2017 to 10/28/2017  [05/06/2017,  10/28/2017]
# 3356  1016768  05/07/2016 to 10/01/2016  [05/07/2016,  10/01/2016]
# 2539  1016770  10/02/2016 to 02/04/2017  [10/02/2016,  02/04/2017]
# 1577  2000005  01/01/2014 to 12/31/2014  [01/01/2014,  12/31/2014]
# 3545  2000021  07/01/2014 to 07/31/2014  [07/01/2014,  07/31/2014]
#
#      SeasonStart    SeasonEnd
# 1397  05/31/2014   10/31/2014
# 5642  05/21/2016   10/29/2016
# 3123  05/23/2015   11/01/2015
# 5865  11/05/2016   04/29/2017
# 4390  06/14/2014   10/11/2014
# ...          ...          ...
# 2266  05/06/2017   10/28/2017
# 3356  05/07/2016   10/01/2016
# 2539  10/02/2016   02/04/2017
# 1577  01/01/2014   12/31/2014
# 3545  07/01/2014   07/31/2014
#
# [5901 rows x 5 columns]

# %%
seasons['MostRecentOpeningDate'] = pd.to_datetime(seasons['SeasonEnd'], errors = 'coerce')
seasons
# Out:
#          FMID                SeasonDate             SeasonDateList  \
# 1397  1000003  05/31/2014 to 10/31/2014  [05/31/2014,  10/31/2014]
# 5642  1000008  05/21/2016 to 10/29/2016  [05/21/2016,  10/29/2016]
# 3123  1000008  05/23/2015 to 11/01/2015  [05/23/2015,  11/01/2015]
# 5865  1000008  11/05/2016 to 04/29/2017  [11/05/2016,  04/29/2017]
# 4390  1000009  06/14/2014 to 10/11/2014  [06/14/2014,  10/11/2014]
# ...       ...                       ...                        ...
# 2266  1012844  05/06/2017 to 10/28/2017  [05/06/2017,  10/28/2017]
# 3356  1016768  05/07/2016 to 10/01/2016  [05/07/2016,  10/01/2016]
# 2539  1016770  10/02/2016 to 02/04/2017  [10/02/2016,  02/04/2017]
# 1577  2000005  01/01/2014 to 12/31/2014  [01/01/2014,  12/31/2014]
# 3545  2000021  07/01/2014 to 07/31/2014  [07/01/2014,  07/31/2014]
#
#      SeasonStart    SeasonEnd MostRecentOpeningDate
# 1397  05/31/2014   10/31/2014            2014-10-31
# 5642  05/21/2016   10/29/2016            2016-10-29
# 3123  05/23/2015   11/01/2015            2015-11-01
# 5865  11/05/2016   04/29/2017            2017-04-29
# 4390  06/14/2014   10/11/2014            2014-10-11
# ...          ...          ...                   ...
# 2266  05/06/2017   10/28/2017            2017-10-28
# 3356  05/07/2016   10/01/2016            2016-10-01
# 2539  10/02/2016   02/04/2017            2017-02-04
# 1577  01/01/2014   12/31/2014            2014-12-31
# 3545  07/01/2014   07/31/2014            2014-07-31
#
# [5901 rows x 6 columns]

# %%
last_season = seasons.groupby('FMID')['MostRecentOpeningDate'].max().reset_index()
last_season
# Out:
#          FMID MostRecentOpeningDate
# 0     1000003            2014-10-31
# 1     1000008            2017-04-29
# 2     1000009            2014-10-11
# 3     1000010                   NaT
# 4     1000011                   NaT
# ...       ...                   ...
# 5387  1012844            2017-10-28
# 5388  1016768            2016-10-01
# 5389  1016770            2017-02-04
# 5390  2000005            2014-12-31
# 5391  2000021            2014-07-31
#
# [5392 rows x 2 columns]

# %%
last_season.to_csv('./data/seasons.csv', index=False)
